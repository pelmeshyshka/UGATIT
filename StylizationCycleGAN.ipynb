# %% [markdown]
# <a href="https://colab.research.google.com/github/pelmeshyshka/UGATIT/blob/master/StylizationCycleGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2337, done.
# remote: Total 2337 (delta 0), reused 0 (delta 0), pack-reused 2337
# Receiving objects: 100% (2337/2337), 8.09 MiB | 40.42 MiB/s, done.
# Resolving deltas: 100% (1499/1499), done.

# %%
import os
os.chdir('pytorch-CycleGAN-and-pix2pix/')

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 686kB 14.1MB/s
# ...
#      |████████████████████████████████| 204kB 52.5MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-cp36-none-any.whl size=655251 sha256=e4af1e0db3b9870756208a55e2a7ee4cf085670ba789674a28fa2d04332079c3
#   Stored in directory: /root/.cache/pip/wheels/70/19/a7/6d589ed967f4dfefd33bc166d081257bd4ed0cb618dccfd62a
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-cp36-none-any.whl size=5711 sha256=698b8e0d83af72d20ea87e2251da831458ab611caf6643310cfee7ed3ff09930
#   Stored in directory: /root/.cache/pip/wheels/b1/c3/d6/9a1cc8f3a99a0fc1124cae20153f36af59a6e683daca0a0814
# Successfully built visdom torchfile
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/My \Drive/
# Out:
# /content/drive/My Drive

# %%
# %cp real.zip /content/pytorch-CycleGAN-and-pix2pix/datasets
# Out:
# cp: cannot stat 'kap2klaus.zip': No such file or directory

# %%
# %cd /content/pytorch-CycleGAN-and-pix2pix/datasets
# Out:
# /content/pytorch-CycleGAN-and-pix2pix/datasets

# %%
# !unzip /content/pytorch-CycleGAN-and-pix2pix/datasets/kap2klaus.zip -d kap2klaus
# Out:
# Archive:  /content/pytorch-CycleGAN-and-pix2pix/datasets/kap2klaus.zip
#   inflating: kap2klaus/testA/frame0.jpg
#   inflating: kap2klaus/testA/frame1023.jpg
#   inflating: kap2klaus/testA/frame1085.jpg
#   inflating: kap2klaus/testA/frame1116.jpg
#   inflating: kap2klaus/testA/frame1209.jpg
#   inflating: kap2klaus/testA/frame124.jpg
#   inflating: kap2klaus/testA/frame1240.jpg
#   inflating: kap2klaus/testA/frame1302.jpg
#   inflating: kap2klaus/testA/frame1364.jpg
#   inflating: kap2klaus/testA/frame1395.jpg
#   inflating: kap2klaus/testA/frame1488.jpg
#   inflating: kap2klaus/testA/frame1519.jpg
#   inflating: kap2klaus/testA/frame1581.jpg
#   inflating: kap2klaus/testA/frame1643.jpg
#   inflating: kap2klaus/testA/frame1674.jpg
#   inflating: kap2klaus/testA/frame1767.jpg
#   inflating: kap2klaus/testA/frame1798.jpg
#   inflating: kap2klaus/testA/frame186.jpg
#   inflating: kap2klaus/testA/frame1860.jpg
#   inflating: kap2klaus/testA/frame1922.jpg
# ...

# %%
# !bash /content/pytorch-CycleGAN-and-pix2pix/datasets/kap2klaus kap2klaus
# Out:
# /content/pytorch-CycleGAN-and-pix2pix/datasets/kap2klaus: /content/pytorch-CycleGAN-and-pix2pix/datasets/kap2klaus: Is a directory

# %%
# %cd /content/pytorch-CycleGAN-and-pix2pix
# Out:
# /content/pytorch-CycleGAN-and-pix2pix

# %%
# !python train.py --dataroot /content/pytorch-CycleGAN-and-pix2pix/datasets/kap2klaus --name kap2klaus --model cycle_gan --checkpoints_dir /content/drive/My\ Drive  --continue_train --save_epoch_freq 1 --save_latest_freq 1000 --epoch_count 173
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: /content/drive/My Drive       	[default: ./checkpoints]
#            continue_train: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: /content/pytorch-CycleGAN-and-pix2pix/datasets/kap2klaus	[default: None]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: 1
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 173                           	[default: 1]
#                  gan_mode: lsgan
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
# ...

# %%
#натренированная модель чтобы переводить только а в б
# %cp ./checkpoints/multi2pulti/latest_net_G_A.pth ./checkpoints/multi2pulti/latest_net_G.pth

# %%
# !python test.py --dataroot /content/pytorch-CycleGAN-and-pix2pix/datasets/kap2klaus/testA --name /content/drive/My\ Drive/kap2klaus --model test --no_dropout --results_dir /content/drive/My\ Drive/result_Klaus --num_test 100 --checkpoints_dir /content/drive/My\ Drive/kap2klaus
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: /content/drive/My Drive/kap2klaus	[default: ./checkpoints]
#                 crop_size: 256
#                  dataroot: /content/pytorch-CycleGAN-and-pix2pix/datasets/kap2klaus/testA	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
# ...
